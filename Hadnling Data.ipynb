# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('Records.csv')

# %%
data.head()
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0  677509        Drs.       Lois              H    Walker      F
# 1  940761         Ms.     Brenda              S  Robinson      F
# 2  428945         Dr.        Joe              W  Robinson      M
# 3  408351        Drs.      Diane              I     Evans      F
# 4  193819         Mr.   Benjamin              R   Russell      M
#
#                          E Mail     Father's Name       Mother's Name  \
# 0       lois.walker@hotmail.com     Donald Walker        Helen Walker
# 1     brenda.robinson@gmail.com  Raymond Robinson       Judy Robinson
# 2        joe.robinson@gmail.com    Scott Robinson  Stephanie Robinson
# 3         diane.evans@yahoo.com       Jason Evans      Michelle Evans
# 4  benjamin.russell@charter.net   Gregory Russell   Elizabeth Russell
#
#   Mother's Maiden Name  ...          SSN    Phone No.     Place Name  \
# 0                Lewis  ...  467-99-4677  303-572-8492        Denver
# ...

# %%
#Categorical Data to Numerical
data['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
data['Name Prefix'].unique()
# Out:
# array(['Drs.', 'Ms.', 'Dr.', 'Mr.', 'Mrs.', 'Hon.', 'Prof.'], dtype=object)

# %%
data['Gender'].value_counts()
# Out:
# F    60
# M    40
# Name: Gender, dtype: int64

# %%
data['Name Prefix'].value_counts()
# Out:
# Ms.      28
# Mr.      25
# Hon.     18
# Mrs.     11
# Drs.      9
# Prof.     5
# Dr.       4
# Name: Name Prefix, dtype: int64

# %% [markdown]
# **-Label Encoding**

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder_X = LabelEncoder()

# %%
label_encoded_data = label_encoder_X.fit_transform(data['Name Prefix'])

# %%
label_encoded_data = pd.DataFrame(data = label_encoded_data, columns = ['Name Prefix'])

# %%
label_encoded_data
# Out:
#     Name Prefix
# 0             1
# 1             5
# 2             0
# 3             1
# 4             3
# ..          ...
# 95            3
# 96            0
# 97            5
# 98            4
# 99            1
#
# [100 rows x 1 columns]

# %%
label_encoded_data['Name Prefix'].unique()

#labels of name prefix is converted into unique numbers(indexes)
# Out:
# array([1, 5, 0, 3, 4, 2, 6])

# %% [markdown]
# **-One Hot Encoding**

# %%
one_hot_encoded_data = pd.get_dummies(data, columns = ['Name Prefix', 'Gender'])

# %%
one_hot_encoded_data
#binary transformation, that creates unique column for each option
#never change labels manually
# Out:
#     Emp ID First Name Middle Initial Last Name                        E Mail  \
# 0   677509       Lois              H    Walker       lois.walker@hotmail.com
# 1   940761     Brenda              S  Robinson     brenda.robinson@gmail.com
# 2   428945        Joe              W  Robinson        joe.robinson@gmail.com
# 3   408351      Diane              I     Evans         diane.evans@yahoo.com
# 4   193819   Benjamin              R   Russell  benjamin.russell@charter.net
# ..     ...        ...            ...       ...                           ...
# 95  639892       Jose              K      Hill         jose.hill@hotmail.com
# 96  704709     Harold              Z    Nelson       harold.nelson@gmail.com
# 97  461593     Nicole              O      Ward         nicole.ward@yahoo.com
# 98  392491    Theresa              R    Murphy      theresa.murphy@gmail.com
# 99  495141      Tammy              B     Young       tammy.young@comcast.net
#
# ...

# %% [markdown]
# **Data Scaling**

# %%
#predicting something we can not train our model just using parametres with not same range.
#For exmaple: house age (range:10-100) and population of location(range: 50000-329000). 
#In this case, population parametre will dominate, so that way we should scale our data

# %%
data1 = pd.read_csv('data.csv')

# %%
data1.head()
# Out:
#          Date  Price (All)  Change (All)  Price (New)  Change (New)  \
# 0  1952-11-01         1891           0.0         2107           0.0
# 1  1953-02-01         1891           0.0         2107           0.0
# 2  1953-05-01         1891           0.0         2107           0.0
# 3  1953-08-01         1881           0.0         2117           0.0
# 4  1953-11-01         1872          -1.0         2117           0.5
#
#    Price (Modern)  Change (Modern)  Price (Older)  Change (Older)
# 0            2020              0.0           1524             0.0
# 1            2002              0.0           1542             0.0
# 2            2002              0.0           1542             0.0
# 3            2002              0.0           1524             0.0
# 4            1975             -2.2           1542             1.2

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
data1 = data1.drop(data1.columns[[8]], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-61-5567d98264a1> in <module>
# ----> 1 data1 = data1.drop(data1.columns[[8]], axis = 1)
#
# C:\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    4109             key = np.asarray(key, dtype=bool)
#    4110
# -> 4111         result = getitem(key)
#    4112         if not is_scalar(result):
#    4113             if np.ndim(result) > 1:
#
# IndexError: index 8 is out of bounds for axis 0 with size 0

# %%
data1.head(5)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]
