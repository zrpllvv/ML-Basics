# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('C:\\Users\\админ\\Jupyter_notebook\\Machine Learning\\Datasets and CSV\\travel.csv')

# %%
data
# Out:
#           Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0     1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1     1/6/2012     08:20     Friday     GSK     51.63     130.3      81.8
# 2     1/4/2012     16:17  Wednesday    Home     51.27     127.4      82.0
# 3     1/4/2012     07:53  Wednesday     GSK     49.17     132.3      74.2
# 4     1/3/2012     18:57    Tuesday    Home     51.15     136.2      83.4
# ..         ...       ...        ...     ...       ...       ...       ...
# 200  7/18/2011     08:09     Monday     GSK     54.52     125.6      49.9
# 201  7/14/2011     08:03   Thursday     GSK     50.90     123.7      76.2
# 202  7/13/2011     17:08  Wednesday    Home     51.96     132.6      57.5
# 203  7/12/2011     17:51    Tuesday    Home     53.28     125.8      61.6
# 204  7/11/2011     16:56     Monday    Home     51.73     125.0      62.8
#
#      AvgMovingSpeed FuelEconomy  TotalTime  MovingTime Take407All Comments
# ...

# %%
data.describe()
# Out:
#          Distance    MaxSpeed    AvgSpeed  AvgMovingSpeed   TotalTime  \
# count  205.000000  205.000000  205.000000      205.000000  205.000000
# mean    50.981512  127.591707   74.477561       81.975610   41.904390
# std      1.321205    4.128450   11.409816       10.111544    6.849476
# min     48.320000  112.200000   38.100000       50.300000   28.200000
# 25%     50.650000  124.900000   68.900000       76.600000   38.400000
# 50%     51.140000  127.400000   73.600000       81.400000   41.300000
# 75%     51.630000  129.800000   79.900000       86.000000   44.400000
# max     60.320000  140.900000  107.700000      112.100000   82.300000
#
#        MovingTime
# count  205.000000
# mean    37.871707
# std      4.835072
# min     27.100000
# 25%     35.700000
# 50%     37.600000
# 75%     39.900000
# max     62.400000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            205 non-null    object
#  1   StartTime       205 non-null    object
#  2   DayOfWeek       205 non-null    object
#  3   GoingTo         205 non-null    object
#  4   Distance        205 non-null    float64
#  5   MaxSpeed        205 non-null    float64
#  6   AvgSpeed        205 non-null    float64
#  7   AvgMovingSpeed  205 non-null    float64
#  8   FuelEconomy     188 non-null    object
#  9   TotalTime       205 non-null    float64
#  10  MovingTime      205 non-null    float64
#  11  Take407All      205 non-null    object
#  12  Comments        24 non-null     object
# dtypes: float64(6), object(7)
# memory usage: 20.9+ KB

# %%
#1 dropping the missing values column-wise.
a = data.dropna(axis = 1)
a
# Out:
#           Date StartTime  DayOfWeek GoingTo  Distance  MaxSpeed  AvgSpeed  \
# 0     1/6/2012     16:37     Friday    Home     51.29     127.4      78.3
# 1     1/6/2012     08:20     Friday     GSK     51.63     130.3      81.8
# 2     1/4/2012     16:17  Wednesday    Home     51.27     127.4      82.0
# 3     1/4/2012     07:53  Wednesday     GSK     49.17     132.3      74.2
# 4     1/3/2012     18:57    Tuesday    Home     51.15     136.2      83.4
# ..         ...       ...        ...     ...       ...       ...       ...
# 200  7/18/2011     08:09     Monday     GSK     54.52     125.6      49.9
# 201  7/14/2011     08:03   Thursday     GSK     50.90     123.7      76.2
# 202  7/13/2011     17:08  Wednesday    Home     51.96     132.6      57.5
# 203  7/12/2011     17:51    Tuesday    Home     53.28     125.8      61.6
# 204  7/11/2011     16:56     Monday    Home     51.73     125.0      62.8
#
#      AvgMovingSpeed  TotalTime  MovingTime Take407All
# ...

# %%
#2 dropping the missing values row-wise

# %%
a = data.dropna(axis = 0)
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 15 to 189
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            23 non-null     object
#  1   StartTime       23 non-null     object
#  2   DayOfWeek       23 non-null     object
#  3   GoingTo         23 non-null     object
#  4   Distance        23 non-null     float64
#  5   MaxSpeed        23 non-null     float64
#  6   AvgSpeed        23 non-null     float64
#  7   AvgMovingSpeed  23 non-null     float64
#  8   FuelEconomy     23 non-null     object
#  9   TotalTime       23 non-null     float64
#  10  MovingTime      23 non-null     float64
#  11  Take407All      23 non-null     object
#  12  Comments        23 non-null     object
# dtypes: float64(6), object(7)
# memory usage: 2.5+ KB

# %%
#3 Using fillna method
cols = ['FuelEconomy', 'Comments']

# %%
data[cols].head()
# Out:
#   FuelEconomy Comments
# 0         NaN      NaN
# 1         NaN      NaN
# 2         NaN      NaN
# 3         NaN      NaN
# 4         NaN      NaN

# %%
data[cols].fillna(value = 999)
# Out:
#     FuelEconomy Comments
# 0           999      999
# 1           999      999
# 2           999      999
# 3           999      999
# 4           999      999
# ..          ...      ...
# 200        7.89      999
# 201        7.89      999
# 202         999      999
# 203         999      999
# 204         999      999
#
# [205 rows x 2 columns]

# %%
#usually you should fill it with mean value, so that distribution and stats won't change

#it also can be
#-mean
#-median
#-mode

# %% [markdown]
# **Using sklearn Imputer**

# %%
from sklearn.impute import SimpleImputer

# %%
imputer_mean = SimpleImputer(missing_values = 'NaN', strategy = 'mean', axis = 0)
imputer_median = SimpleImputer(missing_values = 'NaN', strategy = 'median', axis = 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-a3a968f6977e> in <module>
# ----> 1 imputer_mean = SimpleImputer(missing_values = 'NaN', strategy = 'mean', axis = 0)
#       2 imputer_median = SimpleImputer(missing_values = 'NaN', strategy = 'median', axis = 0)
#
# C:\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# TypeError: __init__() got an unexpected keyword argument 'axis'
